# %% [markdown]
# # Sentiment Analysis on Youtube Comments

# %%
import pandas as pd
import numpy as np
import nltk
nltk.download(['vader_lexicon'])
from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from collections import Counter
import matplotlib.pyplot as plt

# %matplotlib inline
pd.options.mode.chained_assignment = None
pd.set_option('display.max_colwidth', 100)

with open('youtube_comments_clean.csv',encoding="utf8") as file:
    df = pd.read_csv(file)
file.close()
df.head()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\seung\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#    Unnamed: 0  \
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
#
#                                                                   link_title  \
# 0  We Know More About Those COVID-19 Variants. It's Not Great | SciShow News
# 1  We Know More About Those COVID-19 Variants. It's Not Great | SciShow News
# 2  We Know More About Those COVID-19 Variants. It's Not Great | SciShow News
# 3  We Know More About Those COVID-19 Variants. It's Not Great | SciShow News
# 4  We Know More About Those COVID-19 Variants. It's Not Great | SciShow News
#
#    channel   no_of_views time_uploaded  \
# 0  SciShow  85,566 views  Jan 30, 2021
# 1  SciShow  85,566 views  Jan 30, 2021
# 2  SciShow  85,566 views  Jan 30, 2021
# 3  SciShow  85,566 views  Jan 30, 2021
# 4  SciShow  85,566 views  Jan 30, 2021
#
#                                                                                                comment  \
# 0                                            I swear, whoever is playing Plague Inc needs to stop it😤😒
# 1                                   I am getting real tired of being part of  major historical events.
# 2  This channel's COVID reports are a model of how science reporting should be done.  Matter-of-fac...
# 3  To people who understand science, the development of these vaccines in so short of a time frame ...
# 4  So with these new variants this whole thing feels like it will be fought like the flu, at least ...
#
#   upvotes  \
# 0     486
# 1     426
# 2     797
# 3     105
# 4     205
#
#                                                                                            no_contract  \
# 0          ['I', 'swear,', 'whoever', 'is', 'playing', 'Plague', 'Inc', 'needs', 'to', 'stop', 'it😤😒']
# 1  ['I', 'am', 'getting', 'real', 'tired', 'of', 'being', 'part', 'of', 'major', 'historical', 'eve...
# 2  ['This', "channel's", 'COVID', 'reports', 'are', 'a', 'model', 'of', 'how', 'science', 'reportin...
# 3  ['To', 'people', 'who', 'understand', 'science,', 'the', 'development', 'of', 'these', 'vaccines...
# 4  ['So', 'with', 'these', 'new', 'variants', 'this', 'whole', 'thing', 'feels', 'like', 'it', 'wil...
#
#                                                                                           comments_str  \
# 0                                            I swear, whoever is playing Plague Inc needs to stop it😤😒
# 1                                    I am getting real tired of being part of major historical events.
# 2  This channel's COVID reports are a model of how science reporting should be done. Matter-of-fact...
# 3  To people who understand science, the development of these vaccines in so short of a time frame ...
# 4  So with these new variants this whole thing feels like it will be fought like the flu, at least ...
#
#                                                                                              tokenized  \
# 0      ['I', 'swear', ',', 'whoever', 'is', 'playing', 'Plague', 'Inc', 'needs', 'to', 'stop', 'it😤😒']
# 1  ['I', 'am', 'getting', 'real', 'tired', 'of', 'being', 'part', 'of', 'major', 'historical', 'eve...
# 2  ['This', 'channel', "'s", 'COVID', 'reports', 'are', 'a', 'model', 'of', 'how', 'science', 'repo...
# 3  ['To', 'people', 'who', 'understand', 'science', ',', 'the', 'development', 'of', 'these', 'vacc...
# 4  ['So', 'with', 'these', 'new', 'variants', 'this', 'whole', 'thing', 'feels', 'like', 'it', 'wil...
#
#                                                                                                  lower  \
# 0      ['i', 'swear', ',', 'whoever', 'is', 'playing', 'plague', 'inc', 'needs', 'to', 'stop', 'it😤😒']
# 1  ['i', 'am', 'getting', 'real', 'tired', 'of', 'being', 'part', 'of', 'major', 'historical', 'eve...
# 2  ['this', 'channel', "'s", 'covid', 'reports', 'are', 'a', 'model', 'of', 'how', 'science', 'repo...
# 3  ['to', 'people', 'who', 'understand', 'science', ',', 'the', 'development', 'of', 'these', 'vacc...
# 4  ['so', 'with', 'these', 'new', 'variants', 'this', 'whole', 'thing', 'feels', 'like', 'it', 'wil...
#
#                                                                                               no_punct  \
# 0           ['i', 'swear', 'whoever', 'is', 'playing', 'plague', 'inc', 'needs', 'to', 'stop', 'it😤😒']
# 1  ['i', 'am', 'getting', 'real', 'tired', 'of', 'being', 'part', 'of', 'major', 'historical', 'eve...
# 2  ['this', 'channel', "'s", 'covid', 'reports', 'are', 'a', 'model', 'of', 'how', 'science', 'repo...
# 3  ['to', 'people', 'who', 'understand', 'science', 'the', 'development', 'of', 'these', 'vaccines'...
# 4  ['so', 'with', 'these', 'new', 'variants', 'this', 'whole', 'thing', 'feels', 'like', 'it', 'wil...
#
#                                                                                           no_stopwords  \
# 0                            ['swear', 'whoever', 'playing', 'plague', 'inc', 'needs', 'stop', 'it😤😒']
# 1                                ['getting', 'real', 'tired', 'part', 'major', 'historical', 'events']
# 2  ['channel', "'s", 'covid', 'reports', 'model', 'science', 'reporting', 'done', 'matter-of-fact',...
# 3  ['people', 'understand', 'science', 'development', 'vaccines', 'short', 'time', 'frame', 'amazin...
# 4  ['new', 'variants', 'whole', 'thing', 'feels', 'like', 'fought', 'like', 'flu', 'least', 'long',...
#
#                                                                                               pos_tags  \
# 0  [('swear', 'JJ'), ('whoever', 'WP'), ('playing', 'VBG'), ('plague', 'NN'), ('inc', 'NN'), ('need...
# 1  [('getting', 'VBG'), ('real', 'JJ'), ('tired', 'JJ'), ('part', 'NN'), ('major', 'JJ'), ('histori...
# 2  [('channel', 'NN'), ("'s", 'POS'), ('covid', 'NN'), ('reports', 'NNS'), ('model', 'NN'), ('scien...
# 3  [('people', 'NNS'), ('understand', 'VBP'), ('science', 'NN'), ('development', 'NN'), ('vaccines'...
# 4  [('new', 'JJ'), ('variants', 'NNS'), ('whole', 'JJ'), ('thing', 'NN'), ('feels', 'NNS'), ('like'...
#
#                                                                                            wordnet_pos  \
# 0  [('swear', 'a'), ('whoever', 'n'), ('playing', 'v'), ('plague', 'n'), ('inc', 'n'), ('needs', 'v...
# 1  [('getting', 'v'), ('real', 'a'), ('tired', 'a'), ('part', 'n'), ('major', 'a'), ('historical', ...
# 2  [('channel', 'n'), ("'s", 'n'), ('covid', 'n'), ('reports', 'n'), ('model', 'n'), ('science', 'n...
# 3  [('people', 'n'), ('understand', 'v'), ('science', 'n'), ('development', 'n'), ('vaccines', 'n')...
# 4  [('new', 'a'), ('variants', 'n'), ('whole', 'a'), ('thing', 'n'), ('feels', 'n'), ('like', 'n'),...
#
#                                                                                             lemmatized
# 0                                ['swear', 'whoever', 'play', 'plague', 'inc', 'need', 'stop', 'it😤😒']
# 1                                     ['get', 'real', 'tired', 'part', 'major', 'historical', 'event']
# 2  ['channel', "'s", 'covid', 'report', 'model', 'science', 'report', 'do', 'matter-of-fact', 'pres...
# 3  ['people', 'understand', 'science', 'development', 'vaccine', 'short', 'time', 'frame', 'amazing...
# 4  ['new', 'variant', 'whole', 'thing', 'feel', 'like', 'fought', 'like', 'flu', 'least', 'long', '...

# %%
df.drop(['time_uploaded','no_of_views','channel','no_contract','tokenized','lower','no_punct','no_stopwords','pos_tags','wordnet_pos'], axis=1,inplace=True)

# %%
# listify the stringed list
df["lemmatized"] = df["lemmatized"].apply(lambda comment : eval(comment))
df['lemma_str'] = [' '.join(map(str,l)) for l in df['lemmatized']]
df.head()
# Out:
#    Unnamed: 0  \
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
#
#                                                                   link_title  \
# 0  We Know More About Those COVID-19 Variants. It's Not Great | SciShow News
# 1  We Know More About Those COVID-19 Variants. It's Not Great | SciShow News
# 2  We Know More About Those COVID-19 Variants. It's Not Great | SciShow News
# 3  We Know More About Those COVID-19 Variants. It's Not Great | SciShow News
# 4  We Know More About Those COVID-19 Variants. It's Not Great | SciShow News
#
#                                                                                                comment  \
# 0                                            I swear, whoever is playing Plague Inc needs to stop it😤😒
# 1                                   I am getting real tired of being part of  major historical events.
# 2  This channel's COVID reports are a model of how science reporting should be done.  Matter-of-fac...
# 3  To people who understand science, the development of these vaccines in so short of a time frame ...
# 4  So with these new variants this whole thing feels like it will be fought like the flu, at least ...
#
#   upvotes  \
# 0     486
# 1     426
# 2     797
# 3     105
# 4     205
#
#                                                                                           comments_str  \
# 0                                            I swear, whoever is playing Plague Inc needs to stop it😤😒
# 1                                    I am getting real tired of being part of major historical events.
# 2  This channel's COVID reports are a model of how science reporting should be done. Matter-of-fact...
# 3  To people who understand science, the development of these vaccines in so short of a time frame ...
# 4  So with these new variants this whole thing feels like it will be fought like the flu, at least ...
#
#                                                                                             lemmatized  \
# 0                                                [swear, whoever, play, plague, inc, need, stop, it😤😒]
# 1                                                   [get, real, tired, part, major, historical, event]
# 2  [channel, 's, covid, report, model, science, report, do, matter-of-fact, presenting, detail, not...
# 3  [people, understand, science, development, vaccine, short, time, frame, amazing, understand, sci...
# 4                       [new, variant, whole, thing, feel, like, fought, like, flu, least, long, term]
#
#                                                                                              lemma_str
# 0                                                         swear whoever play plague inc need stop it😤😒
# 1                                                           get real tired part major historical event
# 2  channel 's covid report model science report do matter-of-fact presenting detail note limit stud...
# 3  people understand science development vaccine short time frame amazing understand science sound ...
# 4                                    new variant whole thing feel like fought like flu least long term

# %%
sia = SentimentIntensityAnalyzer()

# %%
# make a column of VADER polarity scores, with -1 being most negative and 1 being most positive
df["sentiment_compound"] = df["lemma_str"].apply(lambda comment: sia.polarity_scores(comment)["compound"])

# %%
df.head()
# Out:
#    Unnamed: 0  \
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
#
#                                                                   link_title  \
# 0  We Know More About Those COVID-19 Variants. It's Not Great | SciShow News
# 1  We Know More About Those COVID-19 Variants. It's Not Great | SciShow News
# 2  We Know More About Those COVID-19 Variants. It's Not Great | SciShow News
# 3  We Know More About Those COVID-19 Variants. It's Not Great | SciShow News
# 4  We Know More About Those COVID-19 Variants. It's Not Great | SciShow News
#
#                                                                                                comment  \
# 0                                            I swear, whoever is playing Plague Inc needs to stop it😤😒
# 1                                   I am getting real tired of being part of  major historical events.
# 2  This channel's COVID reports are a model of how science reporting should be done.  Matter-of-fac...
# 3  To people who understand science, the development of these vaccines in so short of a time frame ...
# 4  So with these new variants this whole thing feels like it will be fought like the flu, at least ...
#
#   upvotes  \
# 0     486
# 1     426
# 2     797
# 3     105
# 4     205
#
#                                                                                           comments_str  \
# 0                                            I swear, whoever is playing Plague Inc needs to stop it😤😒
# 1                                    I am getting real tired of being part of major historical events.
# 2  This channel's COVID reports are a model of how science reporting should be done. Matter-of-fact...
# 3  To people who understand science, the development of these vaccines in so short of a time frame ...
# 4  So with these new variants this whole thing feels like it will be fought like the flu, at least ...
#
#                                                                                             lemmatized  \
# 0                                                [swear, whoever, play, plague, inc, need, stop, it😤😒]
# 1                                                   [get, real, tired, part, major, historical, event]
# 2  [channel, 's, covid, report, model, science, report, do, matter-of-fact, presenting, detail, not...
# 3  [people, understand, science, development, vaccine, short, time, frame, amazing, understand, sci...
# 4                       [new, variant, whole, thing, feel, like, fought, like, flu, least, long, term]
#
#                                                                                              lemma_str  \
# 0                                                         swear whoever play plague inc need stop it😤😒
# 1                                                           get real tired part major historical event
# 2  channel 's covid report model science report do matter-of-fact presenting detail note limit stud...
# 3  people understand science development vaccine short time frame amazing understand science sound ...
# 4                                    new variant whole thing feel like fought like flu least long term
#
#    sentiment_compound
# 0              0.0000
# 1             -0.4404
# 2              0.0000
# 3              0.7430
# 4              0.0258

# %%
print(type(df['sentiment_compound']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# graph out sentiment distribution
plt.figure(figsize=(50,30))
plt.xlabel('Sentiment', fontsize=50)
plt.xticks(fontsize=40)
plt.ylabel('Frequency', fontsize=50)
plt.yticks(fontsize=40)
plt.hist(df['sentiment_compound'], bins=50)
plt.title('sentiment Distribution', fontsize=60)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-da02b5dc75ec> in <module>
#       1 # graph out sentiment distribution
# ----> 2 plt.figure(figsize=(50,30))
#       3 plt.xlabel('Sentiment', fontsize=50)
#       4 plt.xticks(fontsize=40)
#       5 plt.ylabel('Frequency', fontsize=50)
#
# NameError: name 'plt' is not defined
